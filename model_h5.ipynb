# %% [markdown]
# <a href="https://colab.research.google.com/github/kimanh24022001/UsingDL-for-nebula-classification-images/blob/main/model_h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from keras.layers import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator   
import tensorflow as tf
import tensorflow.keras

# %%
# Hàm plot ảnh demo đơn giản
def plot_images(img_dir, top=10):
    all_img_dirs = os.listdir(img_dir)
    img_files = [os.path.join(img_dir, file) for file in all_img_dirs][:5]
  
    plt.figure(figsize=(10, 10))
  
    for idx, img_path in enumerate(img_files):
        plt.subplot(5, 5, idx+1)
    
        img = plt.imread(img_path)
        plt.tight_layout()         
        plt.imshow(img, cmap='gray')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
train_dir = '/content/gdrive/MyDrive/train'
val_dir = '/content/gdrive/MyDrive/test'


train_datagen = ImageDataGenerator(rescale=1. / 255,
                                   shear_range=0.1,
                                   rotation_range=50,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True,
                                   validation_split=0.2)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    subset='training',
    seed=20)  # set as training data

validation_generator = train_datagen.flow_from_directory(
    train_dir,  # same directory as training data
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    subset='validation')  # set as validation data
# Out:
# Found 410 images belonging to 13 classes.
# Found 98 images belonging to 13 classes.

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), input_shape=(224,224,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, (1,1), activation='relu'))
#model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Flatten())
model.add(Dropout(0.4))

model.add(Dense(units=120, activation='relu'))
model.add(Dense(13, activation='softmax'))

# %%
def optimizer_init():
    return tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

# %%
model.compile(optimizer=optimizer_init(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  dropout (Dropout)           (None, 12, 12, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 512)       131584
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dropout_1 (Dropout)         (None, 73728)             0
#
#  dense (Dense)               (None, 120)               8847480
#
#  dense_1 (Dense)             (None, 13)                1573
#
# =================================================================
# Total params: 9,369,053
# Trainable params: 9,369,053
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=7)


def upe():
    global epoch_now
    epoch_now += 1


class myCallback(tensorflow.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        upe()


uppe = myCallback()


# Fit model (training)
# history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
#                               validation_data=val_it, validation_steps=len(val_it), epochs=50, verbose=1)
# model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath='check_point/cp.h5',
#     save_weights_only=False,
#     monitor='val_accuracy',
#     mode='max',
#     save_best_only=True,
#     save_freq="epoch")

# class CustomSaver(tf.keras.callbacks.Callback):
#     def on_epoch_end(self, epoch, logs={}):
#         if epoch == 40:  # or save after some epoch, each k-th epoch etc.
#             self.model.save("vgg_epoch_{}.hd5".format(epoch))
#         if epoch == 50:  # or save after some epoch, each k-th epoch etc.
#             self.model.save("vgg_epoch_{}.hd5".format(epoch))
#
#
# saver = CustomSaver()

# callbacks_list = [uppe, es]
callbacks_list = []

# -------------------------------Train-------------------------
epoch = 200
epoch_now = epoch
history = model.fit(train_generator, validation_data=validation_generator, batch_size=64, epochs=epoch, verbose=1,
                    callbacks=callbacks_list)
# Out:
200
# 7/7 [==============================] - 56s 9s/step - loss: 0.2503 - accuracy: 0.9317 - val_loss: 2.2245 - val_accuracy: 0.6327
# Epoch 149/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.2103 - accuracy: 0.9244 - val_loss: 2.0361 - val_accuracy: 0.6020
# Epoch 150/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.2182 - accuracy: 0.9195 - val_loss: 2.5441 - val_accuracy: 0.6122
# Epoch 151/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.2250 - accuracy: 0.9195 - val_loss: 2.3415 - val_accuracy: 0.6939
# Epoch 152/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.1860 - accuracy: 0.9463 - val_loss: 2.4640 - val_accuracy: 0.5918
# Epoch 153/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1704 - accuracy: 0.9317 - val_loss: 2.2905 - val_accuracy: 0.6327
# Epoch 154/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.2246 - accuracy: 0.9171 - val_loss: 2.4279 - val_accuracy: 0.6020
# Epoch 155/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.1961 - accuracy: 0.9268 - val_loss: 2.2359 - val_accuracy: 0.6122
# Epoch 156/200
# 7/7 [==============================] - 60s 8s/step - loss: 0.2596 - accuracy: 0.9049 - val_loss: 2.9343 - val_accuracy: 0.5612
# Epoch 157/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2825 - accuracy: 0.8878 - val_loss: 2.6632 - val_accuracy: 0.5714
# Epoch 158/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2288 - accuracy: 0.9195 - val_loss: 2.4065 - val_accuracy: 0.5612
# Epoch 159/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.4041 - accuracy: 0.8683 - val_loss: 2.2072 - val_accuracy: 0.6224
# Epoch 160/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.3081 - accuracy: 0.8927 - val_loss: 2.3880 - val_accuracy: 0.5918
# Epoch 161/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.3245 - accuracy: 0.8902 - val_loss: 2.4488 - val_accuracy: 0.5714
# Epoch 162/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.3463 - accuracy: 0.8976 - val_loss: 2.4678 - val_accuracy: 0.6020
# Epoch 163/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2658 - accuracy: 0.9098 - val_loss: 2.2703 - val_accuracy: 0.5816
# Epoch 164/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2819 - accuracy: 0.9171 - val_loss: 1.8359 - val_accuracy: 0.6327
# Epoch 165/200
# 7/7 [==============================] - 60s 9s/step - loss: 0.2239 - accuracy: 0.9293 - val_loss: 2.2367 - val_accuracy: 0.6122
# Epoch 166/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2071 - accuracy: 0.9293 - val_loss: 2.3842 - val_accuracy: 0.6122
# Epoch 167/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1867 - accuracy: 0.9317 - val_loss: 2.4175 - val_accuracy: 0.6020
# Epoch 168/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1765 - accuracy: 0.9512 - val_loss: 2.3592 - val_accuracy: 0.5714
# Epoch 169/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1652 - accuracy: 0.9439 - val_loss: 2.6268 - val_accuracy: 0.6122
# Epoch 170/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1974 - accuracy: 0.9463 - val_loss: 2.5485 - val_accuracy: 0.6531
# Epoch 171/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1855 - accuracy: 0.9341 - val_loss: 3.4539 - val_accuracy: 0.6122
# Epoch 172/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2661 - accuracy: 0.8927 - val_loss: 3.0870 - val_accuracy: 0.5612
# Epoch 173/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2561 - accuracy: 0.9122 - val_loss: 3.1206 - val_accuracy: 0.6531
# Epoch 174/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2527 - accuracy: 0.9293 - val_loss: 2.4388 - val_accuracy: 0.5918
# Epoch 175/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.3476 - accuracy: 0.8756 - val_loss: 2.5382 - val_accuracy: 0.6429
# Epoch 176/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2969 - accuracy: 0.8756 - val_loss: 2.9496 - val_accuracy: 0.5510
# Epoch 177/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2473 - accuracy: 0.9171 - val_loss: 2.7335 - val_accuracy: 0.5918
# Epoch 178/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2838 - accuracy: 0.8878 - val_loss: 2.5126 - val_accuracy: 0.6633
# Epoch 179/200
# 7/7 [==============================] - 58s 9s/step - loss: 0.2935 - accuracy: 0.9098 - val_loss: 2.6366 - val_accuracy: 0.5612
# Epoch 180/200
# 7/7 [==============================] - 57s 9s/step - loss: 0.2888 - accuracy: 0.8976 - val_loss: 2.3664 - val_accuracy: 0.6735
# Epoch 181/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2319 - accuracy: 0.9220 - val_loss: 2.4692 - val_accuracy: 0.6224
# Epoch 182/200
# 7/7 [==============================] - 57s 9s/step - loss: 0.1815 - accuracy: 0.9317 - val_loss: 2.5363 - val_accuracy: 0.5918
# Epoch 183/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1939 - accuracy: 0.9415 - val_loss: 2.7037 - val_accuracy: 0.5816
# Epoch 184/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2401 - accuracy: 0.9098 - val_loss: 2.3216 - val_accuracy: 0.6224
# Epoch 185/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1735 - accuracy: 0.9366 - val_loss: 2.8221 - val_accuracy: 0.6224
# Epoch 186/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1870 - accuracy: 0.9366 - val_loss: 2.0357 - val_accuracy: 0.6735
# Epoch 187/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2904 - accuracy: 0.9122 - val_loss: 2.6757 - val_accuracy: 0.5204
# Epoch 188/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.3235 - accuracy: 0.9146 - val_loss: 2.3378 - val_accuracy: 0.6122
# Epoch 189/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1842 - accuracy: 0.9366 - val_loss: 2.6983 - val_accuracy: 0.5714
# Epoch 190/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1736 - accuracy: 0.9390 - val_loss: 2.5220 - val_accuracy: 0.5510
# Epoch 191/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2519 - accuracy: 0.9293 - val_loss: 2.6739 - val_accuracy: 0.6327
# Epoch 192/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1728 - accuracy: 0.9415 - val_loss: 2.3038 - val_accuracy: 0.5918
# Epoch 193/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2007 - accuracy: 0.9244 - val_loss: 2.8138 - val_accuracy: 0.6122
# Epoch 194/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.2225 - accuracy: 0.9146 - val_loss: 2.1655 - val_accuracy: 0.6429
# Epoch 195/200
# 7/7 [==============================] - 56s 9s/step - loss: 0.1962 - accuracy: 0.9341 - val_loss: 2.2036 - val_accuracy: 0.6429
# Epoch 196/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1890 - accuracy: 0.9415 - val_loss: 2.9511 - val_accuracy: 0.5102
# Epoch 197/200
# 7/7 [==============================] - 57s 8s/step - loss: 0.1980 - accuracy: 0.9341 - val_loss: 2.8937 - val_accuracy: 0.6327
# Epoch 198/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.2131 - accuracy: 0.9244 - val_loss: 2.3425 - val_accuracy: 0.6531
# Epoch 199/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.2100 - accuracy: 0.9244 - val_loss: 2.5626 - val_accuracy: 0.6429
# Epoch 200/200
# 7/7 [==============================] - 56s 8s/step - loss: 0.2349 - accuracy: 0.9146 - val_loss: 2.5073 - val_accuracy: 0.6224

# %%
def draw_plt(history, epochs, name='val_accur'):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(16, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.savefig('plt_' + name + '.png')

# %%
model.save("model.h5")
